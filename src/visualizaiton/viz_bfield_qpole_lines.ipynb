# %%
from definitions import *

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import data, figures
from mpl_stylesheets import STYLE_SHEETS_PATHS
plt.style.use(STYLE_SHEETS_PATHS)

# %%
line_30deg_data = pd.read_csv(data.DIR_PATH / 'B_field_qpole_30deg_line.csv')
line_30deg_data['magitude'] = np.sqrt(line_30deg_data['Bx']**2 + line_30deg_data['By']**2 + line_30deg_data['Bz']**2)
line_30deg_data['r'] = np.sqrt(line_30deg_data['x']**2 + line_30deg_data['y']**2 + line_30deg_data['z']**2)

angles = [30, 45, 60, 75, 90]
# angles = [30, 45, 60, 75]
dfs = [
    pd.read_csv(data.DIR_PATH / f'B_field_qpole_{angle}deg_line.csv') for angle in angles
]

for df in dfs:
    df['magnitude'] = np.sqrt(df['Bx']**2 + df['By']**2 + df['Bz']**2)
    df['r'] = np.sqrt(df['x']**2 + df['y']**2 + df['z']**2)

# %%
dfs[-2]
# Out:
#            x         y    z        Bx        By            Bz  magnitude  \
# 0   0.000000  0.000000  0.0  0.000000 -0.000000  0.000000e+00   0.000000
# 1   0.000714  0.000714  0.0 -0.000015 -0.000015 -2.901500e-12   0.000021
# 2   0.001428  0.001428  0.0 -0.000030 -0.000030 -1.158510e-11   0.000042
# 3   0.002143  0.002143  0.0 -0.000045 -0.000044 -2.598820e-11   0.000063
# 4   0.002857  0.002857  0.0 -0.000060 -0.000059 -4.601040e-11   0.000084
# ..       ...       ...  ...       ...       ...           ...        ...
# 95  0.067854  0.067854  0.0  0.000075  0.000074  3.504438e-08   0.000105
# 96  0.068568  0.068568  0.0  0.000075  0.000074  3.512921e-08   0.000105
# 97  0.069282  0.069282  0.0  0.000075  0.000074  3.518765e-08   0.000106
# 98  0.069996  0.069996  0.0  0.000075  0.000074  3.522018e-08   0.000106
# 99  0.070711  0.070711  0.0  0.000075  0.000074  3.522733e-08   0.000106
#
#           r
# 0   0.00000
# 1   0.00101
# 2   0.00202
# 3   0.00303
# 4   0.00404
# ...

# %%
# make a plot of r vs magnitude


# Use a rainbow of colors for the lines
colors = [
    '#000000',  # Red
    '#FF0000',  # Red
    '#FF7F00',  # Orange
    '#00FFFF',  # Cyan
    '#0000FF',  # Blue
    '#7F00FF',  # Purple
]

fig, ax = plt.subplots(figsize=(15, 10))

for df, angle, color in zip(dfs[::-1], angles[::-1], colors):
    ax.plot(df['r']*1000, df['magnitude']*1000, label=f'{angle}°', ms=0, lw=1, alpha=1, color=color, zorder=10)
    
    
ax.set_xlabel('r (mm)')
ax.set_ylabel('B-field magnitude (mT)')

ax.grid(ls='--', lw=0.5, alpha=0.5)

ax.set_xlim(0, 50)
ax.set_ylim(0, 770)
ax.set_xticks(np.arange(0, 51, 10))
ax.set_yticks(np.arange(0, 751, 50))
ax.legend(fontsize=18)
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
# make a plot of r vs magnitude


# Use a rainbow of colors for the lines
colors = [
    '#000000',  # Red
    '#FF0000',  # Red
    '#FF7F00',  # Orange
    '#00FFFF',  # Cyan
    '#0000FF',  # Blue
    '#7F00FF',  # Purple
]

fig, ax = plt.subplots(figsize=(10, 5))

for df, angle, color in zip(dfs[::-1], angles[::-1], colors):
    ax.plot(df['r']*1000, df['magnitude']*1000, label=f'{angle}°', ms=0, lw=1, alpha=1, color=color, zorder=10)
    
    
ax.set_xlabel('r (mm)')
ax.set_ylabel('B-field magnitude (mT)')

ax.grid(ls='--', lw=0.5, alpha=0.5)

ax.set_xlim(0, 100)
ax.set_ylim(0, 0.7)
ax.legend(fontsize=18)
# Out:
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...

# %%
# make a plot of r vs magnitude



fig, ax = plt.subplots(figsize=(10, 5))

for df, angle in zip(dfs, angles):
    ax.plot(line_30deg_data['r']*1000, line_30deg_data['magitude']*1000, label=f'{angle}°', ms=3, lw=2, alpha=0.5)
    
    
ax.set_xlabel('r (mm)')
ax.set_ylabel('B-field magnitude (mT)')

ax.legend()
ax.grid(ls='--', lw=0.5, alpha=0.5)

ax.set_xlim(0, 100)
ax.set_ylim(0, 0.7)
# Out:
# (0.0, 0.7)
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# findfont: Font family 'Times New Roman' not found.
# ...
